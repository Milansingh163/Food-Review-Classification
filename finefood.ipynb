# %%
X = [
     'in this project we are using a pretrained model by google',
    'its 3.3G file, once you load this into your memory ',
    'it occupies ~9Gb, so please do this step only if you have >12G of ram',
    'we will provide a pickle file wich contains a dict , ',
    'and it contains all our courpus words as keys and  model[word] as values',
    'To use this code-snippet, download "GoogleNews-vectors-negative300.bin' ,
]

# %%
y = []

# %%
for i in X:
  y.append(i.split())

# %%
y
# Out:
# [['in',
#   'this',
#   'project',
#   'we',
#   'are',
#   'using',
#   'a',
#   'pretrained',
#   'model',
#   'by',
#   'google'],
#  ['its',
#   '3.3G',
#   'file,',
#   'once',
#   'you',
#   'load',
#   'this',
#   'into',
#   'your',
#   'memory'],
#  ['it',
#   'occupies',
#   '~9Gb,',
#   'so',
#   'please',
#   'do',
#   'this',
#   'step',
#   'only',
#   'if',
#   'you',
#   'have',
#   '>12G',
#   'of',
#   'ram'],
#  ['we',
#   'will',
#   'provide',
#   'a',
#   'pickle',
#   'file',
#   'wich',
#   'contains',
#   'a',
#   'dict',
#   ','],
#  ['and',
#   'it',
#   'contains',
#   'all',
#   'our',
#   'courpus',
#   'words',
#   'as',
#   'keys',
#   'and',
#   'model[word]',
#   'as',
#   'values'],
#  ['To',
#   'use',
#   'this',
#   'code-snippet,',
#   'download',
#   '"GoogleNews-vectors-negative300.bin']]

# %%
from gensim.models import Word2Vec

w2v_model = Word2Vec(y,min_count=1,size=7,workers=4)

# %%
w2v_model.wv.most_similar('all')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('dict', 0.7371817827224731),
#  ('courpus', 0.6762603521347046),
#  ('its', 0.6695964932441711),
#  ('~9Gb,', 0.600581169128418),
#  ('contains', 0.5911043286323547),
#  ('your', 0.5750831365585327),
#  ('To', 0.5446907877922058),
#  ('keys', 0.5111821293830872),
#  ('are', 0.4988986849784851),
#  ('provide', 0.3915749788284302)]

# %%
w2v_model.wv.get_vector('all')
# Out:
# array([-0.05858992, -0.0150505 , -0.06588762,  0.04905392, -0.07089802,
#        -0.06752587, -0.02848848], dtype=float32)
